# %% [markdown]
# # **Chapter 19**
# # **Training and Deploying TensorFlow Models**
#
# **Introduction to TensorFlow**
#
# This chapter focuses on how to train, save, load, and deploy Machine Learning models using TensorFlow. TensorFlow is a powerful open-source framework designed for numerical computation and large-scale Machine Learning. It provides a flexible architecture that allows models to run on CPUs, GPUs, TPUs, and even mobile or embedded devices.
#
# The chapter explains that training a model is only part of the real Machine Learning workflow. In real-world systems, models must be saved, deployed, monitored, updated, and maintained. TensorFlow offers built-in tools that make these steps easier and more reliable, especially for production systems.

# %% [markdown]
# **Using the Keras Sequential API**
#
# The Sequential API is the simplest way to build a neural network in TensorFlow. It is best suited for models that are composed of a single stack of layers, where each layer has exactly one input and one output.
#
# The book demonstrates how to create, compile, and train a neural network using this API.

# %%
import numpy as np
from tensorflow import keras
import tensorflow as tf

tf.random.set_seed(42)
np.random.seed(42)

n_features = 10
X_train = np.random.rand(700, n_features)  # 700 sampel, 10 fitur
y_train = np.random.rand(700, 1)           # target 1D
X_valid = np.random.rand(200, n_features)
y_valid = np.random.rand(200, 1)

model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])

optimizer = keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss="mean_squared_error", optimizer=optimizer, metrics=["mse"])

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3296 - mse: 0.3296 - val_loss: 0.1151 - val_mse: 0.1151
# Epoch 2/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1102 - val_mse: 0.1102
# Epoch 3/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0967 - mse: 0.0967 - val_loss: 0.1080 - val_mse: 0.1080
# Epoch 4/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0945 - mse: 0.0945 - val_loss: 0.1062 - val_mse: 0.1062
# Epoch 5/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0927 - mse: 0.0927 - val_loss: 0.1047 - val_mse: 0.1047
# Epoch 6/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.1034 - val_mse: 0.1034
# Epoch 7/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0896 - mse: 0.0896 - val_loss: 0.1022 - val_mse: 0.1022
# Epoch 8/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0884 - mse: 0.0884 - val_loss: 0.1012 - val_mse: 0.1012
# Epoch 9/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0873 - mse: 0.0873 - val_loss: 0.1002 - val_mse: 0.1002
# Epoch 10/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0863 - mse: 0.0863 - val_loss: 0.0994 - val_mse: 0.0994
# Epoch 11/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0987 - val_mse: 0.0987
# Epoch 12/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.0980 - val_mse: 0.0980
# Epoch 13/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0841 - mse: 0.0841 - val_loss: 0.0974 - val_mse: 0.0974
# Epoch 14/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 15/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.0964 - val_mse: 0.0964
# Epoch 16/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0825 - mse: 0.0825 - val_loss: 0.0959 - val_mse: 0.0959
# Epoch 17/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.0955 - val_mse: 0.0955
# Epoch 18/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0817 - mse: 0.0817 - val_loss: 0.0951 - val_mse: 0.0951
# Epoch 19/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0813 - mse: 0.0813 - val_loss: 0.0948 - val_mse: 0.0948
# Epoch 20/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0944 - val_mse: 0.0944

# %% [markdown]
# **Saving and Restoring Models**
#
# Once a model has been trained, it must be saved so it can be reused later without retraining. TensorFlow allows saving both:
#
# The model architecture
#
# The trained weights
#
# The optimizer state

# %%
model.save("my_keras_model.h5")

model = keras.models.load_model("my_keras_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# **Callbacks**
#
# Callbacks are functions that are executed during training at specific moments, such as:
#
# End of an epoch
#
# When performance stops improving
#
# When training should stop early

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

X_train = np.random.rand(100, 10)  # 100 sampel, 10 fitur
y_train = np.random.rand(100, 1)   # 100 target
X_valid = np.random.rand(20, 10)   # 20 sampel validasi
y_valid = np.random.rand(20, 1)

model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])

model.compile(loss="mean_squared_error", optimizer="sgd")

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "my_keras_model.h5", save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(
    patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=100,
    validation_data=(X_valid, y_valid),
    callbacks=[checkpoint_cb, early_stopping_cb]
)
# Out:
# Epoch 1/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0800
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0969 - val_loss: 0.0899
# Epoch 2/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0790
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0957 - val_loss: 0.0892
# Epoch 3/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0783
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0948 - val_loss: 0.0888
# Epoch 4/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0778
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0940 - val_loss: 0.0886
# Epoch 5/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0774
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0932 - val_loss: 0.0884
# Epoch 6/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0770
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0926 - val_loss: 0.0882
# Epoch 7/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0919 - val_loss: 0.0882
# Epoch 8/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0763
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0913 - val_loss: 0.0882
# Epoch 9/100
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0760
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0908 - val_loss: 0.0881
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0902 - val_loss: 0.0882
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0897 - val_loss: 0.0882
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0892 - val_loss: 0.0882
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0887 - val_loss: 0.0883
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0883 - val_loss: 0.0883
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0878 - val_loss: 0.0884
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0874 - val_loss: 0.0885
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0870 - val_loss: 0.0885
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0866 - val_loss: 0.0886
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0863 - val_loss: 0.0887

# %% [markdown]
# **Using TensorBoard for Visualization**
#
# TensorBoard is TensorFlow’s visualization tool. It allows monitoring:
#
# Training and validation loss
#
# Model graphs
#
# Histograms of weights and gradients

# %%
tensorboard_cb = keras.callbacks.TensorBoard("logs")

history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid),
                    callbacks=[tensorboard_cb])
# Out:
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0902 - val_loss: 0.0882
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0897 - val_loss: 0.0882
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0892 - val_loss: 0.0882
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0887 - val_loss: 0.0883
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0883 - val_loss: 0.0883
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0878 - val_loss: 0.0884
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0874 - val_loss: 0.0885
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0870 - val_loss: 0.0885
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0866 - val_loss: 0.0886
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0863 - val_loss: 0.0887
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0859 - val_loss: 0.0888
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0855 - val_loss: 0.0888
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0852 - val_loss: 0.0890
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0849 - val_loss: 0.0890
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0845 - val_loss: 0.0891
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0842 - val_loss: 0.0892
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0839 - val_loss: 0.0892
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0836 - val_loss: 0.0894
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0834 - val_loss: 0.0895
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0831 - val_loss: 0.0895
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0828 - val_loss: 0.0896
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0826 - val_loss: 0.0897
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0823 - val_loss: 0.0897
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0821 - val_loss: 0.0899
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0819 - val_loss: 0.0899
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0817 - val_loss: 0.0901
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0815 - val_loss: 0.0902
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0813 - val_loss: 0.0903
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0811 - val_loss: 0.0904
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0809 - val_loss: 0.0905

# %% [markdown]
# **Fine-Tuning Neural Network Hyperparameters**
#
# Hyperparameters such as learning rate, number of layers, and number of neurons strongly influence performance. The book introduces Keras Tuner to automate this process.

# %%
def build_model(hp):
    model = keras.models.Sequential()
    model.add(keras.layers.Dense(
        hp.Int("units", min_value=10, max_value=100, step=10),
        activation="relu"))
    model.add(keras.layers.Dense(1))
    model.compile(loss="mse",
                  optimizer=keras.optimizers.SGD(
                      hp.Float("learning_rate", min_value=1e-4,
                               max_value=1e-2, sampling="log")))
    return model

# %% [markdown]
# **Deploying TensorFlow Models**
#
# The final step is deployment. Models can be deployed:
#
# As part of a web application
#
# Through a REST API
#
# On cloud platforms such as Google Cloud AI Platform
#
# The chapter emphasizes that deployment must include:
#
# Monitoring
#
# Logging
#
# Retraining strategies
#
# Version control
#
# Deployment is not the end of the project but the beginning of continuous maintenance.

# %% [markdown]
# **Chapter 19 Key Takeaways**
#
# TensorFlow provides tools for training, saving, tuning, and deploying models
#
# Keras APIs simplify model building
#
# Callbacks and TensorBoard are essential for production-ready training
#
# Deployment requires planning, monitoring, and automation
